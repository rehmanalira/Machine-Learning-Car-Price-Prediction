# %%
import pandas as pd

# %%
car=pd.read_csv('carprice.csv')

# %%
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car.drop('car_ID',inplace=True,axis=1)

# %%
car.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %%
#GETTING DUMMIES VALUES

# %%
car_name=pd.get_dummies(car['CarName'])

# %%
car.drop('CarName',axis=1,inplace=True)

# %%
car.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8      64.1  ...         130        mpfi
# 1          front       88.6      168.8      64.1  ...         130        mpfi
# 2          front       94.5      171.2      65.5  ...         152        mpfi
# 3          front       99.8      176.6      66.2  ...         109        mpfi
# 4          front       99.4      176.6      66.4  ...         136        mpfi
#
#   boreratio stroke  compressionratio horsepower  peakrpm  citympg  highwaympg  \
# ...

# %%
fuel_type=pd.get_dummies(car['fueltype'])

# %%
fuel_type.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
door_number=pd.get_dummies('doornumber')

# %%
door_number.head()
# Out:
#    doornumber
# 0           1

# %%
car_body=pd.get_dummies('carbody')
car_body.head()
# Out:
#    carbody
# 0        1

# %%
fuel_system=pd.get_dummies('fuelsystem')
fuel_system.head()
# Out:
#    fuelsystem
# 0           1

# %%
car.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8      64.1  ...         130        mpfi
# 1          front       88.6      168.8      64.1  ...         130        mpfi
# 2          front       94.5      171.2      65.5  ...         152        mpfi
# 3          front       99.8      176.6      66.2  ...         109        mpfi
# 4          front       99.4      176.6      66.4  ...         136        mpfi
#
#   boreratio stroke  compressionratio horsepower  peakrpm  citympg  highwaympg  \
# ...

# %%
car=pd.concat([car,car_body,door_number,fuel_type],axis=1)

# %%
car.head()
# Out:
#    symboling fueltype aspiration  doornumber      carbody drivewheel  \
# 0          3      gas        std         two  convertible        rwd
# 1          3      gas        std         two  convertible        rwd
# 2          1      gas        std         two    hatchback        rwd
# 3          2      gas        std        four        sedan        fwd
# 4          2      gas        std        four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  compressionratio  \
# 0          front       88.6      168.8      64.1  ...               9.0
# 1          front       88.6      168.8      64.1  ...               9.0
# 2          front       94.5      171.2      65.5  ...               9.0
# 3          front       99.8      176.6      66.2  ...              10.0
# 4          front       99.4      176.6      66.4  ...               8.0
#
#    horsepower peakrpm citympg  highwaympg    price  carbody  doornumber  \
# ...

# %%
car.drop(['fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation'],axis=1,inplace=True)

# %%
car.head()
# Out:
#    symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          3       88.6      168.8      64.1       48.8        2548
# 1          3       88.6      168.8      64.1       48.8        2548
# 2          1       94.5      171.2      65.5       52.4        2823
# 3          2       99.8      176.6      66.2       54.3        2337
# 4          2       99.4      176.6      66.4       54.3        2824
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 0       dohc           four         130       mpfi       3.47    2.68
# 1       dohc           four         130       mpfi       3.47    2.68
# 2       ohcv            six         152       mpfi       2.68    3.47
# 3        ohc           four         109       mpfi       3.19    3.40
# 4        ohc           five         136       mpfi       3.19    3.40
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg    price  \
# ...

# %%
cylinder_number=pd.get_dummies('cylindernumber')
cylinder_number.head()
# Out:
#    cylindernumber
# 0               1

# %%
car=pd.concat([car,cylinder_number],axis=1)

# %%
car.head()
# Out:
#    symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          3       88.6      168.8      64.1       48.8        2548
# 1          3       88.6      168.8      64.1       48.8        2548
# 2          1       94.5      171.2      65.5       52.4        2823
# 3          2       99.8      176.6      66.2       54.3        2337
# 4          2       99.4      176.6      66.4       54.3        2824
#
#   enginetype  cylindernumber  enginesize fuelsystem  ...  stroke  \
# 0       dohc            four         130       mpfi  ...    2.68
# 1       dohc            four         130       mpfi  ...    2.68
# 2       ohcv             six         152       mpfi  ...    3.47
# 3        ohc            four         109       mpfi  ...    3.40
# 4        ohc            five         136       mpfi  ...    3.40
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg    price  \
# 0               9.0         111     5000       21          27  13495.0
# ...

# %%
# car.drop(['cylindernumber'],axis=1,inplace=True) # here i all deleted the colums

# %%
car.head()
# Out:
#    symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          3       88.6      168.8      64.1       48.8        2548
# 1          3       88.6      168.8      64.1       48.8        2548
# 2          1       94.5      171.2      65.5       52.4        2823
# 3          2       99.8      176.6      66.2       54.3        2337
# 4          2       99.4      176.6      66.4       54.3        2824
#
#   enginetype  cylindernumber  enginesize fuelsystem  ...  stroke  \
# 0       dohc            four         130       mpfi  ...    2.68
# 1       dohc            four         130       mpfi  ...    2.68
# 2       ohcv             six         152       mpfi  ...    3.47
# 3        ohc            four         109       mpfi  ...    3.40
# 4        ohc            five         136       mpfi  ...    3.40
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg    price  \
# 0               9.0         111     5000       21          27  13495.0
# ...

# %%
##Droping NUll Values

# %%
car.dropna(axis=1)
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0            3       88.6      168.8      64.1       48.8        2548
# 1            3       88.6      168.8      64.1       48.8        2548
# 2            1       94.5      171.2      65.5       52.4        2823
# 3            2       99.8      176.6      66.2       54.3        2337
# 4            2       99.4      176.6      66.4       54.3        2824
# ..         ...        ...        ...       ...        ...         ...
# 200         -1      109.1      188.8      68.9       55.5        2952
# 201         -1      109.1      188.8      68.8       55.5        3049
# 202         -1      109.1      188.8      68.9       55.5        3012
# 203         -1      109.1      188.8      68.9       55.5        3217
# 204         -1      109.1      188.8      68.9       55.5        3062
#
#     enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# ...

# %%
car.isnull().sum()
# Out:
# symboling             0
# wheelbase             0
# carlength             0
# carwidth              0
# carheight             0
# curbweight            0
# enginetype            0
# cylindernumber        0
# enginesize            0
# fuelsystem            0
# boreratio             0
# stroke                0
# compressionratio      0
# horsepower            0
# peakrpm               0
# citympg               0
# highwaympg            0
# price                 0
# diesel                0
# gas                   0
# cylindernumber      204
# dtype: int64

# %% [markdown]
# ## Train Test Spliting

# %%
from sklearn.model_selection import train_test_split

# %%
train_set,test_set=train_test_split(car,test_size=0.2,random_state=42)

# %%
print(f"Number OF test{len(train_set)} \n and number of tests {len(test_set)}  ")
# Out:
# Number OF test164
#  and number of tests 41

# %%
car=train_set.copy()

# %% [markdown]
# ## Taking Data for train and test in test set

# %%
car.head()
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 66           0      104.9      175.0      66.1       54.4        2700
# 111          0      107.9      186.7      68.4       56.7        3075
# 153          0       95.7      169.7      63.6       59.1        2280
# 96           1       94.5      165.3      63.8       54.5        1971
# 38           0       96.5      167.5      65.2       53.3        2289
#
#     enginetype  cylindernumber  enginesize fuelsystem  ...  stroke  \
# 66         ohc            four         134        idi  ...    3.64
# 111          l            four         120       mpfi  ...    2.19
# 153        ohc            four          92       2bbl  ...    3.03
# 96         ohc            four          97       2bbl  ...    3.29
# 38         ohc            four         110       1bbl  ...    3.58
#
#      compressionratio  horsepower  peakrpm  citympg  highwaympg    price  \
# ...

# %%
car.drop(['enginetype','cylindernumber'],axis=1,inplace=True)

# %% [markdown]
# ## Coorelation

# %%
car['price'].sort_values(ascending=False)
# Out:
# 74     45400.0
# 128    37028.0
# 17     36880.0
# 49     36000.0
# 48     35550.0
#         ...
# 32      5399.0
# 76      5389.0
# 150     5348.0
# 50      5195.0
# 138     5118.0
# Name: price, Length: 164, dtype: float64

# %%
car_features=car.drop('price',axis=1)
car_labels=car['price'].copy()

# %%
car.drop('fuelsystem',axis=True,inplace=True)

# %%
car.head()
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 66           0      104.9      175.0      66.1       54.4        2700
# 111          0      107.9      186.7      68.4       56.7        3075
# 153          0       95.7      169.7      63.6       59.1        2280
# 96           1       94.5      165.3      63.8       54.5        1971
# 38           0       96.5      167.5      65.2       53.3        2289
#
#      enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 66          134       3.43    3.64              22.0          72     4200
# 111         120       3.46    2.19               8.4          95     5000
# 153          92       3.05    3.03               9.0          62     4800
# 96           97       3.15    3.29               9.4          69     5200
# 38          110       3.15    3.58               9.0          86     5800
#
#      citympg  highwaympg    price  diesel  gas
# 66        31          39  18344.0       1    0
# ...

# %% [markdown]
# ## Creating The Pipe Line

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

my_pipeline=Pipeline([
    ('std_scaler', StandardScaler())
])

# %% [markdown]
# ## Model Selection

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(car_features,car_labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-77ccc0883ed8> in <module>
#       1 model=LinearRegression()
# ----> 2 model.fit(car_features,car_labels)
#
# c:\python38\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# c:\python38\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ...

# %%
some_data=car_features.iloc[:5]
some_label=car_labels.iloc[:5]

# %%
prdeict_data=my_pipeline.transform(some_data)
